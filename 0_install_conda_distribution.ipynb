# %% [markdown]
# # Install Anaconda distribution 🐍

# %% [markdown]
# ## 1. Go [here](https://www.anaconda.com/download) and sign up

# %% [markdown]
# ![alt text](./utils/a_anaconda.png)

# %% [markdown]
# ![alt text](./utils/b_anaconda.png)

# %% [markdown]
# # 2. Install Anaconda Distribution for your system

# %% [markdown]
# ![alt text](./utils/c_anaconda.png)

# %% [markdown]
# # 3. Create conda environment

# %% [markdown]
# ```bash
# conda create -n AR python=3.9
# ```

# %% [markdown]
# # 4. Activate conda environment

# %% [markdown]
# ```bash
# conda activate AR
# ```

# %% [markdown]
# # 5. Install requirements

# %% [markdown]
# ```bash
# pip install -r requirements.txt
# ```
